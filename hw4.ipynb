# %% [markdown]
# # Домашня робота №4

# %% [markdown]
# # Дискретні розподіли

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1 Від'ємний біноміальний розподіл

# %% [markdown]
# Більш детальна інформація в [документації](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.nbinom.html).

# %%
n = 5
p = 0.4

# %%
from scipy.stats import nbinom
from scipy.stats import poisson

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import nbinom
from scipy.stats import poisson

x = np.arange(-8, 30)
pmf = nbinom.pmf(x, n, p)
plt.figure(figsize=(8, 5))
plt.stem(x, pmf, basefmt=" ")
plt.title(f'Негативний біноміальний розподіл (r={n}, p={p})')
plt.xlabel('Кількість невдач')
plt.ylabel('Ймовірність')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1.1 Щільність

# %%
x = np.arange(-0.5, n*5+1, 0.5)

# %% [markdown]
# Виведіть значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
pmf_values = nbinom.pmf(x, n, p)
x_int = x.astype(int)

for xi, pi in zip(x_int, pmf_values):
    print(f"PMF({xi}) = {pi:.4f}")
# Out:
# PMF(0) = 0.0000
# PMF(0) = 0.0102
# PMF(0) = 0.0000
# PMF(1) = 0.0307
# PMF(1) = 0.0000
# PMF(2) = 0.0553
# PMF(2) = 0.0000
# PMF(3) = 0.0774
# PMF(3) = 0.0000
# PMF(4) = 0.0929
# PMF(4) = 0.0000
# PMF(5) = 0.1003
# PMF(5) = 0.0000
# PMF(6) = 0.1003
# PMF(6) = 0.0000
# PMF(7) = 0.0946
# PMF(7) = 0.0000
# PMF(8) = 0.0851
# PMF(8) = 0.0000
# PMF(9) = 0.0738
# PMF(9) = 0.0000
# PMF(10) = 0.0620
# PMF(10) = 0.0000
# PMF(11) = 0.0507
# PMF(11) = 0.0000
# PMF(12) = 0.0406
# PMF(12) = 0.0000
# PMF(13) = 0.0318
# PMF(13) = 0.0000
# PMF(14) = 0.0246
# PMF(14) = 0.0000
# PMF(15) = 0.0187
# PMF(15) = 0.0000
# PMF(16) = 0.0140
# PMF(16) = 0.0000
# PMF(17) = 0.0104
# PMF(17) = 0.0000
# PMF(18) = 0.0076
# PMF(18) = 0.0000
# PMF(19) = 0.0055
# PMF(19) = 0.0000
# PMF(20) = 0.0040
# PMF(20) = 0.0000
# PMF(21) = 0.0028
# PMF(21) = 0.0000
# PMF(22) = 0.0020
# PMF(22) = 0.0000
# PMF(23) = 0.0014
# PMF(23) = 0.0000
# PMF(24) = 0.0010
# PMF(24) = 0.0000
# PMF(25) = 0.0007
# PMF(25) = 0.0000

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
plt.figure(figsize=(8, 5))
plt.stem(x, pmf_values, basefmt=" ")
plt.title(f"Функція ймовірності від'ємного біноміального розподілу (n={n}, p={p})")
plt.xlabel('Кількість невдач (x)')
plt.ylabel('Ймовірність P(X = x)')
plt.grid(True)
plt.show()

# %% [markdown]
# Зобразіть графічно значення функції щільності від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x1$.

# %%
x1 = np.arange(0, n*5+1)

# %%
x1 = np.arange(0, n*5+1)
pmf = nbinom.pmf(x1, n, p)

plt.figure(figsize=(8, 5))
plt.stem(x1, pmf, basefmt=" ")
plt.title(f'PMF від\'ємного біноміального розподілу (n={n}, p={p})')
plt.xlabel('Кількість невдач до n успіхів')
plt.ylabel('P(X = x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1.2 Функція розподілу

# %% [markdown]
# Виведіть значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
cdf = nbinom.cdf(x, n, p)
for xi, ci in zip(x, cdf):
    print(f'CDF({xi}) = {ci:.4f}')
# Out:
# CDF(-0.5) = 0.0000
# CDF(0.0) = 0.0102
# CDF(0.5) = 0.0102
# CDF(1.0) = 0.0410
# CDF(1.5) = 0.0410
# CDF(2.0) = 0.0963
# CDF(2.5) = 0.0963
# CDF(3.0) = 0.1737
# CDF(3.5) = 0.1737
# CDF(4.0) = 0.2666
# CDF(4.5) = 0.2666
# CDF(5.0) = 0.3669
# CDF(5.5) = 0.3669
# CDF(6.0) = 0.4672
# CDF(6.5) = 0.4672
# CDF(7.0) = 0.5618
# CDF(7.5) = 0.5618
# CDF(8.0) = 0.6470
# CDF(8.5) = 0.6470
# CDF(9.0) = 0.7207
# CDF(9.5) = 0.7207
# CDF(10.0) = 0.7827
# CDF(10.5) = 0.7827
# CDF(11.0) = 0.8334
# CDF(11.5) = 0.8334
# CDF(12.0) = 0.8740
# CDF(12.5) = 0.8740
# CDF(13.0) = 0.9058
# CDF(13.5) = 0.9058
# CDF(14.0) = 0.9304
# CDF(14.5) = 0.9304
# CDF(15.0) = 0.9490
# CDF(15.5) = 0.9490
# CDF(16.0) = 0.9630
# CDF(16.5) = 0.9630
# CDF(17.0) = 0.9734
# CDF(17.5) = 0.9734
# CDF(18.0) = 0.9810
# CDF(18.5) = 0.9810
# CDF(19.0) = 0.9866
# CDF(19.5) = 0.9866
# CDF(20.0) = 0.9905
# CDF(20.5) = 0.9905
# CDF(21.0) = 0.9934
# CDF(21.5) = 0.9934
# CDF(22.0) = 0.9954
# CDF(22.5) = 0.9954
# CDF(23.0) = 0.9968
# CDF(23.5) = 0.9968
# CDF(24.0) = 0.9978
# CDF(24.5) = 0.9978
# CDF(25.0) = 0.9985
# CDF(25.5) = 0.9985

# %% [markdown]
# Зобразіть графічно значення функції розподілу від'ємного біноміального розподілу з параметрами $n, p$ в точках вектора $x$.

# %%
plt.figure(figsize=(8,5))
plt.step(x, cdf, where='post')
plt.title(f'CDF від\'ємного біноміального розподілу (n={n}, p={p})')
plt.xlabel('Кількість невдач до n успіхів')
plt.ylabel('F(X ≤ x)')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 1.3 Випадкові величини

# %% [markdown]
# Згенеруйте $100$ випадкових величин з від'ємного біноміального розподілу з параметрами $n, p$.

# %%
lst = []

for _ in range(0, 100):
    lst.append(nbinom.rvs(n, p))
    
for el in lst:
    print(el, end=" ")
# Out:
# 11 6 2 10 9 5 8 11 14 15 7 1 7 5 9 9 10 8 11 7 6 1 6 2 5 12 22 13 3 2 1 3 11 8 3 8 1 5 10 5 4 6 6 12 6 9 11 8 7 25 0 6 6 5 8 7 2 6 9 10 11 8 4 10 6 7 4 7 8 9 8 12 6 3 6 13 13 13 8 7 5 3 7 6 9 6 5 4 5 11 4 11 6 3 10 17 7 9 10 16

# %% [markdown]
# Виведіть кількість кожного елемента в отриманому випадковому векторі.

# %%
d = dict()

for el in lst:
    if el in d:
        d[el] += 1
    else:
        d[el] = 1

for key, value in d.items():
    print(f"count of {value} = {key}")
# Out:
# count of 8 = 11
# count of 15 = 6
# count of 4 = 2
# count of 7 = 10
# count of 8 = 9
# count of 9 = 5
# count of 10 = 8
# count of 1 = 14
# count of 1 = 15
# count of 10 = 7
# count of 4 = 1
# count of 3 = 12
# count of 1 = 22
# count of 4 = 13
# count of 6 = 3
# count of 5 = 4
# count of 1 = 25
# count of 1 = 0
# count of 1 = 17
# count of 1 = 16

# %% [markdown]
# Зобразіть графічно кількість кожного елемента в отриманому випадковому векторі.

# %%
plt.figure(figsize=(8,5))
x = list(d.keys())
y = list(d.values())
plt.stem(x, y, basefmt=" ")
plt.xlabel("Value")
plt.ylabel("Count")
plt.title("Frequency of each value")
plt.grid(True)
plt.show()
plt.show()

# %% [markdown]
# ### 3 Розподіл Пуассона

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та гістограму $10000$ випадкових величин розподілу Пуассона з параметрами:
# 1. $\mu = 0.1$
# 2. $\mu = 0.2$
# 3. $\mu = 0.3$
# 4. $\mu = 0.4$
# 5. $\mu = 0.5$
# 6. $\mu = 0.6$
# 7. $\mu = 0.7$
# 8. $\mu = 0.8$
# 9. $\mu = 0.9$

# %%
mus = np.arange(0.1, 1.0, 0.1)

for mu in mus:

    x = np.arange(0, int(mu*5)+1)
    pmf = poisson.pmf(x, mu)
    cdf = poisson.cdf(x, mu)
    sample = poisson.rvs(mu, size=10000)
    
    # PMF
    plt.figure(figsize=(8,5))
    plt.stem(x, pmf, basefmt=" ")
    plt.title(f'PMF Poisson(μ={mu:.1f})')
    plt.xlabel('k')
    plt.ylabel('P(X=k)')
    plt.grid(True)
    plt.show()
    
    # CDF
    plt.figure(figsize=(8,5))
    plt.step(x, cdf, where='post')
    plt.title(f'CDF Poisson(μ={mu:.1f})')
    plt.xlabel('k')
    plt.ylabel('F(X≤k)')
    plt.grid(True)
    plt.show()
    
    # Гістограма + теоретична PMF
    plt.figure(figsize=(8,5))
    plt.hist(sample, bins=x-0.5, density=True)
    plt.stem(x, pmf, basefmt=" ")
    plt.title(f'Histogram vs PMF Poisson(μ={mu:.1f})')
    plt.xlabel('k')
    plt.ylabel('Relative frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## 4 Апроксимація біноміального розподілу розподілом Пуассона

# %% [markdown]
# Покажіть схожість біноміального розподілу та розподілу Пуассона (їх функцій щільності) з відповідними параметрами.
# Наприклад:
# - $n = 100, p = 0.05$
# - $n = 100, p = 0.1$
# - $n = 100, p = 0.15$
# - $n = 100, p = 0.2$
# - $n = 100, p = 0.35$
# - $n = 100, p = 0.5$
# - $n = 100, p = 0.75$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom, poisson

n = 100
ps = [0.05, 0.1, 0.15, 0.2, 0.35, 0.5, 0.75]

for p in ps:
    lam = n * p
    x = np.arange(0, int(lam + 4*np.sqrt(lam)) + 1)
    
    pmf_bin = binom.pmf(x, n, p)
    pmf_poi = poisson.pmf(x, lam)
    
    plt.figure(figsize=(8,4))
    plt.stem(x, pmf_bin, basefmt=" ", label="Binomial(n=100,p={:.2f})".format(p))
    plt.stem(x, pmf_poi, basefmt=" ", linefmt='C1-', markerfmt='C1o', label="Poisson(λ={:.2f})".format(lam))
    plt.title(f"Binomial vs Poisson PMF (n=100, p={p:.2f}, λ={lam:.2f})")
    plt.xlabel("k")
    plt.ylabel("Probability")
    plt.legend()
    plt.grid(True)
    plt.show()
